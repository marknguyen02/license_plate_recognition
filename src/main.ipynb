# %%
from ultralytics import YOLO
import re
import cv2
import easyocr
import numpy as np
import os

model = YOLO('../runs/train/weights/best.pt')
ocr_reader = easyocr.Reader(['en'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
results = model.val()
print(f'Precision: {results.results_dict['metrics/precision(B)']}')
print(f'Recall: {results.results_dict['metrics/recall(B)']}')
# Out:
# Ultralytics 8.3.47  Python-3.12.6 torch-2.5.1+cpu CPU (12th Gen Intel Core(TM) i5-12500H)
# Model summary (fused): 168 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning D:\VSCodeProjects\LicensePlateRecognition\dataset\labels\val.cache... 1145 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1145/1145 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 72/72 [02:42<00:00,  2.26s/it]
#                    all       1145       1313       0.98      0.972      0.992      0.837
#           LicensePlate        409        410      0.976      0.983      0.993      0.807
#           LicensePlate        753        903      0.983       0.96      0.991      0.868
# Speed: 2.4ms preprocess, 112.2ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to D:\runs\detect\val
# Precision: 0.9796212948511402
# Recall: 0.971514603136906

# %%
# Xác định các bounding boxes
def detect(image):
    detection_results = model(image)
    bounding_boxes = []

    # Duyệt qua từng bounding box được phát hiện
    for detected_box in detection_results[0].boxes:
        # Thêm bounding box vào danh sách
        bounding_boxes.append(detected_box.xyxy[0].tolist())

    return bounding_boxes


# Chuẩn hoá kết quả nhận diện
def normalize(ocr_result):
    # Giữ lại các ký tự chữ cái (a-z, A-Z), số (0-9)
    normalized_result = re.sub(r'[^a-zA-Z0-9]', '', ocr_result)
    
    # Thay thế ký tự thứ 3 theo điều kiện
    if len(normalized_result) >= 3:
        normalized_chars = {'8' : 'B', '2' : 'Z', '7': 'Z', '4' : 'A', '5' : 'S', '0' : 'O'}
        thirst_char = normalized_result[2]
        if thirst_char in normalized_chars:
            normalized_result = normalized_result[:2] + normalized_chars[thirst_char] + normalized_result[3:]

    return normalized_result

# Nhận diện và trả về văn bản
def recognize(image):
    bounding_boxes = detect(image)
    result_texts = []
    for x_min, y_min, x_max, y_max in bounding_boxes:
        # Cắt vùng biển số từ ảnh
        cropped_plate = image[int(y_min):int(y_max), int(x_min):int(x_max)]

        # Chuyển đổi sang ảnh grayscale
        gray_plate = cv2.cvtColor(cropped_plate, cv2.COLOR_BGR2GRAY)

        # Xử lý tăng cường hình ảnh
        blurred_plate = cv2.GaussianBlur(gray_plate, (5, 5), 0)
        kernel = np.ones((5, 5), np.uint8)
        top_hat = cv2.morphologyEx(blurred_plate, cv2.MORPH_TOPHAT, kernel)
        black_hat = cv2.morphologyEx(blurred_plate, cv2.MORPH_BLACKHAT, kernel)
        enhanced_plate = cv2.add(blurred_plate, top_hat)
        enhanced_plate = cv2.subtract(enhanced_plate, black_hat)

        # Nhận diện ký tự trên biển số bằng OCR
        ocr_results = ocr_reader.readtext(np.array(enhanced_plate))

        # Lấy nội dung ký tự từ kết quả OCR
        plate_text = ''.join([text[-2] for text in sorted(ocr_results, key=lambda x: x[0][0][1])])

        # Chuẩn hoá kết quả
        normalized_text = normalize(plate_text)

        # Thêm vào danh sách kết quả
        result_texts.append(normalized_text)

    return result_texts

# %%
# Cắt ảnh sử dụng mô hình YOLO
def crop_image_using_yolo(original_image, margin=50):
    bounding_boxes = detect(original_image)
    # Danh sách các vùng đã cắt từ ảnh
    cropped_images = [original_image[int(y_min):int(y_max), int(x_min):int(x_max)] for
                      x_min, y_min, x_max, y_max in
                      bounding_boxes]
    if not cropped_images:
        return None

    # Tạo lưới hiển thị
    # Số hàng/cột của lưới
    grid_size = int(np.ceil(np.sqrt(len(cropped_images))))
    # Kích thước ảnh nhỏ (thumbnail)
    thumb_size = 150
    grid_height = grid_size * (thumb_size + margin) - margin
    # Tạo nền trắng
    grid_width = grid_size * (thumb_size + margin) - margin
    crop_image = np.zeros((grid_height, grid_width, 3), dtype=np.uint8) + 0

    for idx, cropped_image in enumerate(cropped_images):
        if cropped_image.size > 0:
            # Resize vùng cắt thành kích thước thumbnail
            thumbnail = cv2.resize(cropped_image, (thumb_size, thumb_size))
            row = idx // grid_size
            col = idx % grid_size
            # Xác định vị trí chèn thumbnail vào lưới, bao gồm margin
            start_y = row * (thumb_size + margin)
            start_x = col * (thumb_size + margin)
            crop_image[start_y:start_y + thumb_size, start_x:start_x + thumb_size, :] = thumbnail
    return crop_image

def show_cropped_images(dir_path):
    for filename in os.listdir(dir_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            file_path = os.path.join(dir_path, filename)
            original_image = cv2.imread(file_path)

            cropped_image = crop_image_using_yolo(original_image)

            # Hiển thị kết quả
            before_img_name = f"{filename} - Before cropped"
            after_img_name = f"{filename} - After cropped"

            cv2.imshow(before_img_name, original_image)
            cv2.moveWindow(before_img_name, 100, 100)

            cv2.imshow(after_img_name, cropped_image)
            cv2.moveWindow(after_img_name, 120 + original_image.shape[1], 100)

            cv2.waitKey(0)
            cv2.destroyAllWindows()

show_cropped_images('../data/cropped_data')
# Out:
# 0: 416x640 2 LicensePlates, 122.3ms
# Speed: 8.0ms preprocess, 122.3ms inference, 9.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 512x640 4 LicensePlates, 128.8ms
# Speed: 5.0ms preprocess, 128.8ms inference, 6.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 416x640 1 LicensePlate, 107.5ms
# Speed: 3.0ms preprocess, 107.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 480x640 1 LicensePlate, 121.9ms
# Speed: 4.0ms preprocess, 121.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
def process_image(image):
    texts = recognize(image)
    bounding_boxes = detect(image)

    for text, (x_min, y_min, x_max, y_max) in zip(texts, bounding_boxes):
        cv2.rectangle(image, (int(x_min), int(y_min)), (int(x_max), int(y_max)), (0, 255, 0), 2)
        cv2.putText(image, text, (int(x_min), int(y_min) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
    return image

path_dir = '../data/main_data/images'
for filename in os.listdir(path_dir):
    img = cv2.imread(os.path.join(path_dir, filename))
    processed_image = process_image(img)
    cv2.imshow('Processed Image', processed_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# 0: 640x416 1 LicensePlate, 132.1ms
# Speed: 7.0ms preprocess, 132.1ms inference, 9.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 66.3ms
# Speed: 2.0ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)

# %%
def process_image(image):
    texts = recognize(image)
    bounding_boxes = detect(image)

    for text, (x_min, y_min, x_max, y_max) in zip(texts, bounding_boxes):
        cv2.rectangle(image, (int(x_min), int(y_min)), (int(x_max), int(y_max)), (0, 255, 0), 2)
        cv2.putText(image, text, (int(x_min), int(y_min) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
    return image

def process_camera():
    cap = cv2.VideoCapture(0)
    
    if not cap.isOpened():
        print("Không thể mở camera")
        return

    while True:
        ret, frame = cap.read()
        if not ret:
            break  

        processed_frame = process_image(frame)
        cv2.imshow('Processed Camera Feed', processed_frame)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()


process_camera()

# %%
def process_image(image):
    texts = recognize(image)
    bounding_boxes = detect(image)

    for text, (x_min, y_min, x_max, y_max) in zip(texts, bounding_boxes):
        cv2.rectangle(image, (int(x_min), int(y_min)), (int(x_max), int(y_max)), (0, 255, 0), 2)
        cv2.putText(image, text, (int(x_min), int(y_min) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
    return image

def display_video(input_video_path, output_video_path):
    cap = cv2.VideoCapture(input_video_path)
    
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break  

        processed_frame = process_image(frame)
        out.write(processed_frame)
        cv2.imshow('Processed Video', processed_frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    cap.release()
    out.release()
    cv2.destroyAllWindows()

display_video('../data/video_data/inputs/input2.mp4', '../data/video_data/outputs/output2.mp4')
# Out:
# 0: 384x640 1 LicensePlate, 199.1ms
# Speed: 6.2ms preprocess, 199.1ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 100.2ms
# Speed: 2.0ms preprocess, 100.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 153.6ms
# Speed: 4.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 97.9ms
# Speed: 2.0ms preprocess, 97.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 110.3ms
# Speed: 3.0ms preprocess, 110.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 110.0ms
# Speed: 1.9ms preprocess, 110.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 130.1ms
# Speed: 4.0ms preprocess, 130.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 118.0ms
# Speed: 2.0ms preprocess, 118.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 138.0ms
# Speed: 3.0ms preprocess, 138.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 147.6ms
# Speed: 2.0ms preprocess, 147.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 141.0ms
# Speed: 3.0ms preprocess, 141.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 195.9ms
# Speed: 7.1ms preprocess, 195.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 178.0ms
# Speed: 4.0ms preprocess, 178.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 140.0ms
# Speed: 3.0ms preprocess, 140.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 136.0ms
# Speed: 3.0ms preprocess, 136.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 131.0ms
# Speed: 3.0ms preprocess, 131.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 134.0ms
# Speed: 4.0ms preprocess, 134.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 101.9ms
# Speed: 1.0ms preprocess, 101.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 122.1ms
# Speed: 5.0ms preprocess, 122.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 94.0ms
# Speed: 2.0ms preprocess, 94.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 103.9ms
# Speed: 2.8ms preprocess, 103.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 95.9ms
# Speed: 2.0ms preprocess, 95.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 102.0ms
# Speed: 3.8ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 90.2ms
# Speed: 1.0ms preprocess, 90.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 101.9ms
# Speed: 3.0ms preprocess, 101.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 113.9ms
# Speed: 2.1ms preprocess, 113.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 112.2ms
# Speed: 4.0ms preprocess, 112.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 94.0ms
# Speed: 2.1ms preprocess, 94.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 96.1ms
# Speed: 3.1ms preprocess, 96.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 96.7ms
# Speed: 2.1ms preprocess, 96.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 104.6ms
# Speed: 3.0ms preprocess, 104.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 92.7ms
# Speed: 1.0ms preprocess, 92.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 104.6ms
# Speed: 2.8ms preprocess, 104.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 96.6ms
# Speed: 2.0ms preprocess, 96.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 104.5ms
# Speed: 2.9ms preprocess, 104.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 87.9ms
# Speed: 1.1ms preprocess, 87.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 94.3ms
# Speed: 1.8ms preprocess, 94.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 87.9ms
# Speed: 1.0ms preprocess, 87.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 110.6ms
# Speed: 4.0ms preprocess, 110.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 84.0ms
# Speed: 2.1ms preprocess, 84.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 101.5ms
# Speed: 3.8ms preprocess, 101.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 86.1ms
# Speed: 2.0ms preprocess, 86.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 98.6ms
# Speed: 2.9ms preprocess, 98.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 90.0ms
# Speed: 1.9ms preprocess, 90.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 99.8ms
# Speed: 2.7ms preprocess, 99.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 90.0ms
# Speed: 2.1ms preprocess, 90.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 97.3ms
# Speed: 4.0ms preprocess, 97.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 86.0ms
# Speed: 2.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 100.5ms
# Speed: 2.9ms preprocess, 100.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 89.7ms
# Speed: 2.1ms preprocess, 89.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 107.7ms
# Speed: 5.1ms preprocess, 107.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 88.0ms
# Speed: 1.9ms preprocess, 88.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 100.1ms
# Speed: 2.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 93.0ms
# Speed: 1.0ms preprocess, 93.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 105.2ms
# Speed: 2.0ms preprocess, 105.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 85.9ms
# Speed: 1.0ms preprocess, 85.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 105.2ms
# Speed: 3.8ms preprocess, 105.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 89.9ms
# Speed: 1.0ms preprocess, 89.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 105.3ms
# Speed: 3.0ms preprocess, 105.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 85.7ms
# Speed: 1.9ms preprocess, 85.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 95.9ms
# Speed: 4.0ms preprocess, 95.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 90.6ms
# Speed: 1.9ms preprocess, 90.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 105.9ms
# Speed: 4.0ms preprocess, 105.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 102.9ms
# Speed: 1.9ms preprocess, 102.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 106.5ms
# Speed: 5.0ms preprocess, 106.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 89.3ms
# Speed: 2.0ms preprocess, 89.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 104.2ms
# Speed: 2.9ms preprocess, 104.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 96.3ms
# Speed: 2.0ms preprocess, 96.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 110.7ms
# Speed: 3.0ms preprocess, 110.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 98.7ms
# Speed: 2.0ms preprocess, 98.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 112.6ms
# Speed: 3.1ms preprocess, 112.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 97.1ms
# Speed: 1.0ms preprocess, 97.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 104.7ms
# Speed: 2.9ms preprocess, 104.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 89.4ms
# Speed: 1.0ms preprocess, 89.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 98.5ms
# Speed: 2.9ms preprocess, 98.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 90.3ms
# Speed: 1.0ms preprocess, 90.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 106.7ms
# Speed: 3.0ms preprocess, 106.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 94.0ms
# Speed: 1.9ms preprocess, 94.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 100.9ms
# Speed: 1.9ms preprocess, 100.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 94.0ms
# Speed: 2.0ms preprocess, 94.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 103.4ms
# Speed: 1.8ms preprocess, 103.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 93.1ms
# Speed: 2.0ms preprocess, 93.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 108.8ms
# Speed: 1.9ms preprocess, 108.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 92.2ms
# Speed: 1.9ms preprocess, 92.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 105.9ms
# Speed: 1.9ms preprocess, 105.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 94.6ms
# Speed: 2.0ms preprocess, 94.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 110.1ms
# Speed: 4.0ms preprocess, 110.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 93.3ms
# Speed: 2.0ms preprocess, 93.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 112.3ms
# Speed: 3.8ms preprocess, 112.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 94.5ms
# Speed: 1.9ms preprocess, 94.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 115.8ms
# Speed: 2.8ms preprocess, 115.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 90.9ms
# Speed: 1.0ms preprocess, 90.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 109.5ms
# Speed: 1.9ms preprocess, 109.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 91.4ms
# Speed: 1.8ms preprocess, 91.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 110.6ms
# Speed: 2.9ms preprocess, 110.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 98.0ms
# Speed: 2.0ms preprocess, 98.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 112.0ms
# Speed: 2.0ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 109.8ms
# Speed: 2.0ms preprocess, 109.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 110.1ms
# Speed: 2.9ms preprocess, 110.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 98.6ms
# Speed: 1.9ms preprocess, 98.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 118.6ms
# Speed: 2.9ms preprocess, 118.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 113.3ms
# Speed: 3.1ms preprocess, 113.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 99.7ms
# Speed: 1.0ms preprocess, 99.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 113.3ms
# Speed: 4.0ms preprocess, 113.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 106.9ms
# Speed: 2.0ms preprocess, 106.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 124.6ms
# Speed: 2.8ms preprocess, 124.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 101.7ms
# Speed: 2.0ms preprocess, 101.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 134.8ms
# Speed: 2.9ms preprocess, 134.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 206.0ms
# Speed: 2.0ms preprocess, 206.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 115.7ms
# Speed: 6.0ms preprocess, 115.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 115.0ms
# Speed: 2.0ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 127.0ms
# Speed: 5.0ms preprocess, 127.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 131.0ms
# Speed: 3.0ms preprocess, 131.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 169.0ms
# Speed: 3.0ms preprocess, 169.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 106.7ms
# Speed: 3.0ms preprocess, 106.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 141.5ms
# Speed: 4.0ms preprocess, 141.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 92.0ms
# Speed: 1.0ms preprocess, 92.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 114.7ms
# Speed: 2.0ms preprocess, 114.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 164.2ms
# Speed: 2.0ms preprocess, 164.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 172.0ms
# Speed: 5.9ms preprocess, 172.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 101.0ms
# Speed: 2.0ms preprocess, 101.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 131.8ms
# Speed: 3.9ms preprocess, 131.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 98.0ms
# Speed: 2.0ms preprocess, 98.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 129.5ms
# Speed: 3.8ms preprocess, 129.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 115.0ms
# Speed: 2.0ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 124.7ms
# Speed: 2.9ms preprocess, 124.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 93.0ms
# Speed: 2.1ms preprocess, 93.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 96.4ms
# Speed: 2.0ms preprocess, 96.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 98.0ms
# Speed: 2.0ms preprocess, 98.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 105.7ms
# Speed: 4.0ms preprocess, 105.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 100.0ms
# Speed: 2.0ms preprocess, 100.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 129.6ms
# Speed: 6.0ms preprocess, 129.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 105.9ms
# Speed: 2.0ms preprocess, 105.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 135.7ms
# Speed: 6.0ms preprocess, 135.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 97.0ms
# Speed: 3.0ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 119.3ms
# Speed: 4.0ms preprocess, 119.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 141.3ms
# Speed: 2.0ms preprocess, 141.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 92.0ms
# Speed: 2.0ms preprocess, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 127.0ms
# Speed: 3.9ms preprocess, 127.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 97.0ms
# Speed: 2.0ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 103.9ms
# Speed: 5.0ms preprocess, 103.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 102.0ms
# Speed: 3.0ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 121.7ms
# Speed: 8.0ms preprocess, 121.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 93.0ms
# Speed: 4.0ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 101.2ms
# Speed: 5.0ms preprocess, 101.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 98.0ms
# Speed: 2.0ms preprocess, 98.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 103.5ms
# Speed: 6.1ms preprocess, 103.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 95.0ms
# Speed: 1.0ms preprocess, 95.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 102.2ms
# Speed: 3.0ms preprocess, 102.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 89.0ms
# Speed: 4.0ms preprocess, 89.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 108.6ms
# Speed: 3.0ms preprocess, 108.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 97.0ms
# Speed: 2.0ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 110.0ms
# Speed: 2.9ms preprocess, 110.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 88.0ms
# Speed: 2.0ms preprocess, 88.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 99.0ms
# Speed: 3.0ms preprocess, 99.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 93.0ms
# Speed: 3.0ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 100.3ms
# Speed: 3.0ms preprocess, 100.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 89.2ms
# Speed: 2.0ms preprocess, 89.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 96.7ms
# Speed: 3.0ms preprocess, 96.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 93.0ms
# Speed: 4.0ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 96.4ms
# Speed: 4.0ms preprocess, 96.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 111.0ms
# Speed: 2.0ms preprocess, 111.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 111.5ms
# Speed: 3.2ms preprocess, 111.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 123.9ms
# Speed: 3.0ms preprocess, 123.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 132.7ms
# Speed: 4.0ms preprocess, 132.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 134.6ms
# Speed: 3.0ms preprocess, 134.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 118.5ms
# Speed: 5.9ms preprocess, 118.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 95.0ms
# Speed: 2.0ms preprocess, 95.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 111.6ms
# Speed: 2.0ms preprocess, 111.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.2ms
# Speed: 2.0ms preprocess, 98.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 95.7ms
# Speed: 4.9ms preprocess, 95.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 111.2ms
# Speed: 3.1ms preprocess, 111.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.6ms
# Speed: 2.0ms preprocess, 106.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 115.4ms
# Speed: 6.0ms preprocess, 115.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.2ms
# Speed: 2.0ms preprocess, 98.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 124.8ms
# Speed: 1.9ms preprocess, 124.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 108.0ms
# Speed: 1.9ms preprocess, 108.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 131.8ms
# Speed: 2.1ms preprocess, 131.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 110.9ms
# Speed: 3.0ms preprocess, 110.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 125.8ms
# Speed: 3.0ms preprocess, 125.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 133.9ms
# Speed: 2.0ms preprocess, 133.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 116.3ms
# Speed: 3.0ms preprocess, 116.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 124.8ms
# Speed: 1.9ms preprocess, 124.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 127.4ms
# Speed: 5.1ms preprocess, 127.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 126.6ms
# Speed: 1.9ms preprocess, 126.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 120.1ms
# Speed: 2.0ms preprocess, 120.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.7ms
# Speed: 2.9ms preprocess, 95.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 112.2ms
# Speed: 1.9ms preprocess, 112.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.2ms
# Speed: 1.0ms preprocess, 99.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 107.0ms
# Speed: 2.9ms preprocess, 107.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 111.9ms
# Speed: 3.9ms preprocess, 111.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 124.2ms
# Speed: 2.9ms preprocess, 124.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 155.0ms
# Speed: 3.0ms preprocess, 155.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 136.9ms
# Speed: 3.0ms preprocess, 136.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 121.0ms
# Speed: 2.0ms preprocess, 121.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 102.8ms
# Speed: 6.0ms preprocess, 102.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 102.1ms
# Speed: 2.9ms preprocess, 102.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 111.8ms
# Speed: 2.9ms preprocess, 111.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 105.0ms
# Speed: 1.9ms preprocess, 105.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 112.4ms
# Speed: 2.7ms preprocess, 112.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 97.0ms
# Speed: 1.9ms preprocess, 97.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.9ms
# Speed: 2.8ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 93.8ms
# Speed: 1.9ms preprocess, 93.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 102.2ms
# Speed: 1.9ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 94.3ms
# Speed: 1.9ms preprocess, 94.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.1ms
# Speed: 1.9ms preprocess, 98.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 109.4ms
# Speed: 1.9ms preprocess, 109.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 91.0ms
# Speed: 2.0ms preprocess, 91.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.0ms
# Speed: 2.9ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.5ms
# Speed: 3.0ms preprocess, 89.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 96.9ms
# Speed: 3.1ms preprocess, 96.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 93.2ms
# Speed: 1.9ms preprocess, 93.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.8ms
# Speed: 1.8ms preprocess, 98.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 94.7ms
# Speed: 2.1ms preprocess, 94.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.9ms
# Speed: 1.8ms preprocess, 100.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 96.5ms
# Speed: 2.0ms preprocess, 96.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.5ms
# Speed: 3.0ms preprocess, 101.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 93.8ms
# Speed: 1.9ms preprocess, 93.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.0ms
# Speed: 1.9ms preprocess, 98.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 93.6ms
# Speed: 1.9ms preprocess, 93.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.4ms
# Speed: 2.0ms preprocess, 100.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 94.1ms
# Speed: 1.9ms preprocess, 94.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.8ms
# Speed: 2.9ms preprocess, 98.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 93.7ms
# Speed: 2.0ms preprocess, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 110.3ms
# Speed: 4.0ms preprocess, 110.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 131.4ms
# Speed: 2.0ms preprocess, 131.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.0ms
# Speed: 2.0ms preprocess, 101.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.2ms
# Speed: 2.1ms preprocess, 95.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 94.3ms
# Speed: 2.9ms preprocess, 94.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 92.0ms
# Speed: 1.0ms preprocess, 92.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 98.8ms
# Speed: 2.1ms preprocess, 98.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 88.9ms
# Speed: 2.9ms preprocess, 88.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 101.1ms
# Speed: 2.9ms preprocess, 101.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 93.5ms
# Speed: 1.9ms preprocess, 93.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 105.3ms
# Speed: 2.9ms preprocess, 105.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 92.6ms
# Speed: 3.0ms preprocess, 92.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.9ms
# Speed: 2.9ms preprocess, 101.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 97.5ms
# Speed: 2.0ms preprocess, 97.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.6ms
# Speed: 3.0ms preprocess, 100.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 102.1ms
# Speed: 3.0ms preprocess, 102.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.4ms
# Speed: 3.0ms preprocess, 104.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 96.9ms
# Speed: 2.0ms preprocess, 96.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 105.2ms
# Speed: 2.1ms preprocess, 105.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.4ms
# Speed: 1.0ms preprocess, 100.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.5ms
# Speed: 2.1ms preprocess, 106.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.6ms
# Speed: 2.0ms preprocess, 98.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 102.5ms
# Speed: 2.8ms preprocess, 102.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.5ms
# Speed: 1.0ms preprocess, 99.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 107.7ms
# Speed: 2.9ms preprocess, 107.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 93.1ms
# Speed: 2.0ms preprocess, 93.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 106.3ms
# Speed: 2.0ms preprocess, 106.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 100.3ms
# Speed: 1.9ms preprocess, 100.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 103.9ms
# Speed: 2.2ms preprocess, 103.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 106.9ms
# Speed: 2.0ms preprocess, 106.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 115.0ms
# Speed: 2.9ms preprocess, 115.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 99.1ms
# Speed: 3.0ms preprocess, 99.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 92.2ms
# Speed: 2.0ms preprocess, 92.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 109.3ms
# Speed: 3.1ms preprocess, 109.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 93.4ms
# Speed: 2.0ms preprocess, 93.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 103.4ms
# Speed: 1.9ms preprocess, 103.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 92.6ms
# Speed: 1.0ms preprocess, 92.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 102.0ms
# Speed: 2.9ms preprocess, 102.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 96.9ms
# Speed: 3.0ms preprocess, 96.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 105.2ms
# Speed: 1.8ms preprocess, 105.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 91.3ms
# Speed: 2.0ms preprocess, 91.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 105.7ms
# Speed: 3.0ms preprocess, 105.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 99.1ms
# Speed: 2.0ms preprocess, 99.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 102.0ms
# Speed: 3.0ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 93.5ms
# Speed: 2.0ms preprocess, 93.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 105.8ms
# Speed: 2.0ms preprocess, 105.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 95.9ms
# Speed: 2.1ms preprocess, 95.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 105.8ms
# Speed: 3.0ms preprocess, 105.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 99.4ms
# Speed: 1.9ms preprocess, 99.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 103.6ms
# Speed: 3.0ms preprocess, 103.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 96.5ms
# Speed: 1.0ms preprocess, 96.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 105.9ms
# Speed: 1.9ms preprocess, 105.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 91.9ms
# Speed: 2.0ms preprocess, 91.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 108.4ms
# Speed: 2.9ms preprocess, 108.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 93.3ms
# Speed: 1.0ms preprocess, 93.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 107.6ms
# Speed: 2.9ms preprocess, 107.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 96.0ms
# Speed: 2.1ms preprocess, 96.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 110.8ms
# Speed: 4.1ms preprocess, 110.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 95.2ms
# Speed: 2.0ms preprocess, 95.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 108.9ms
# Speed: 3.9ms preprocess, 108.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 93.3ms
# Speed: 1.9ms preprocess, 93.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 112.3ms
# Speed: 2.9ms preprocess, 112.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 98.6ms
# Speed: 1.8ms preprocess, 98.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 106.2ms
# Speed: 3.0ms preprocess, 106.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 98.7ms
# Speed: 2.0ms preprocess, 98.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 103.6ms
# Speed: 2.8ms preprocess, 103.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 90.6ms
# Speed: 2.1ms preprocess, 90.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 101.1ms
# Speed: 2.0ms preprocess, 101.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 99.7ms
# Speed: 1.9ms preprocess, 99.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 100.4ms
# Speed: 3.9ms preprocess, 100.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 94.4ms
# Speed: 1.9ms preprocess, 94.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 102.4ms
# Speed: 2.9ms preprocess, 102.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 94.6ms
# Speed: 1.0ms preprocess, 94.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 104.1ms
# Speed: 1.9ms preprocess, 104.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 97.5ms
# Speed: 2.0ms preprocess, 97.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 97.4ms
# Speed: 2.9ms preprocess, 97.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 90.5ms
# Speed: 2.0ms preprocess, 90.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 138.3ms
# Speed: 3.0ms preprocess, 138.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 92.2ms
# Speed: 2.0ms preprocess, 92.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 107.6ms
# Speed: 2.8ms preprocess, 107.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 92.4ms
# Speed: 1.0ms preprocess, 92.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 108.0ms
# Speed: 2.9ms preprocess, 108.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 94.2ms
# Speed: 1.9ms preprocess, 94.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 103.6ms
# Speed: 3.0ms preprocess, 103.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 95.6ms
# Speed: 1.9ms preprocess, 95.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 104.5ms
# Speed: 4.0ms preprocess, 104.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 89.4ms
# Speed: 1.9ms preprocess, 89.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 105.0ms
# Speed: 2.1ms preprocess, 105.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 92.0ms
# Speed: 1.0ms preprocess, 92.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 103.7ms
# Speed: 3.0ms preprocess, 103.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 89.7ms
# Speed: 2.0ms preprocess, 89.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 102.4ms
# Speed: 3.0ms preprocess, 102.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 96.3ms
# Speed: 2.0ms preprocess, 96.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 102.2ms
# Speed: 3.0ms preprocess, 102.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 89.7ms
# Speed: 1.9ms preprocess, 89.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 107.3ms
# Speed: 4.0ms preprocess, 107.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 97.4ms
# Speed: 1.9ms preprocess, 97.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 107.0ms
# Speed: 3.0ms preprocess, 107.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 99.9ms
# Speed: 1.0ms preprocess, 99.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 111.1ms
# Speed: 2.9ms preprocess, 111.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 89.6ms
# Speed: 1.9ms preprocess, 89.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 99.8ms
# Speed: 3.0ms preprocess, 99.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 101.1ms
# Speed: 1.9ms preprocess, 101.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 104.8ms
# Speed: 2.1ms preprocess, 104.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 147.3ms
# Speed: 2.0ms preprocess, 147.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 122.2ms
# Speed: 4.9ms preprocess, 122.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 155.0ms
# Speed: 2.0ms preprocess, 155.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 126.0ms
# Speed: 6.0ms preprocess, 126.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 104.6ms
# Speed: 2.0ms preprocess, 104.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 98.2ms
# Speed: 2.0ms preprocess, 98.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 99.0ms
# Speed: 2.0ms preprocess, 99.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 96.9ms
# Speed: 2.0ms preprocess, 96.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 98.0ms
# Speed: 2.0ms preprocess, 98.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 85.7ms
# Speed: 1.0ms preprocess, 85.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 98.8ms
# Speed: 2.0ms preprocess, 98.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 93.2ms
# Speed: 2.0ms preprocess, 93.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 122.1ms
# Speed: 4.0ms preprocess, 122.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 107.2ms
# Speed: 2.0ms preprocess, 107.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 103.1ms
# Speed: 1.9ms preprocess, 103.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 87.3ms
# Speed: 2.0ms preprocess, 87.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 97.3ms
# Speed: 2.9ms preprocess, 97.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 97.9ms
# Speed: 1.9ms preprocess, 97.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 101.4ms
# Speed: 5.0ms preprocess, 101.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 96.0ms
# Speed: 2.0ms preprocess, 96.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 104.3ms
# Speed: 4.0ms preprocess, 104.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 87.0ms
# Speed: 3.0ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 84.2ms
# Speed: 2.9ms preprocess, 84.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 81.0ms
# Speed: 2.0ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 82.6ms
# Speed: 2.9ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 81.0ms
# ...
#
# 0: 384x640 1 LicensePlate, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 81.7ms
# Speed: 3.2ms preprocess, 81.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 77.0ms
# Speed: 1.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 81.5ms
# Speed: 2.0ms preprocess, 81.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 103.7ms
# Speed: 2.0ms preprocess, 103.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 80.5ms
# Speed: 2.1ms preprocess, 80.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 82.0ms
# Speed: 3.0ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 85.1ms
# Speed: 1.9ms preprocess, 85.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 77.0ms
# Speed: 2.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 82.9ms
# Speed: 3.1ms preprocess, 82.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 80.0ms
# Speed: 2.0ms preprocess, 80.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 98.3ms
# Speed: 2.0ms preprocess, 98.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 83.0ms
# Speed: 2.0ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 91.2ms
# Speed: 2.0ms preprocess, 91.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 101.4ms
# Speed: 3.0ms preprocess, 101.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 98.1ms
# Speed: 4.0ms preprocess, 98.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 86.4ms
# Speed: 2.0ms preprocess, 86.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 101.1ms
# Speed: 1.9ms preprocess, 101.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 91.8ms
# Speed: 1.0ms preprocess, 91.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 100.8ms
# Speed: 3.1ms preprocess, 100.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 89.3ms
# Speed: 1.0ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 94.3ms
# Speed: 2.8ms preprocess, 94.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 83.0ms
# Speed: 1.0ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 102.5ms
# Speed: 3.0ms preprocess, 102.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 110.0ms
# Speed: 3.0ms preprocess, 110.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 104.4ms
# Speed: 4.9ms preprocess, 104.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 91.0ms
# Speed: 3.0ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 82.9ms
# Speed: 2.1ms preprocess, 82.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 81.0ms
# Speed: 2.0ms preprocess, 81.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 106.8ms
# Speed: 3.0ms preprocess, 106.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 99.0ms
# Speed: 2.0ms preprocess, 99.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 92.6ms
# Speed: 2.0ms preprocess, 92.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 97.0ms
# Speed: 2.0ms preprocess, 97.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 100.8ms
# Speed: 3.9ms preprocess, 100.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 87.2ms
# Speed: 4.1ms preprocess, 87.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 82.0ms
# Speed: 3.0ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 95.6ms
# Speed: 3.0ms preprocess, 95.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 84.5ms
# Speed: 4.0ms preprocess, 84.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 82.6ms
# Speed: 3.8ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 82.6ms
# Speed: 2.8ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 83.8ms
# Speed: 2.0ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 77.1ms
# Speed: 2.0ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 82.2ms
# Speed: 4.0ms preprocess, 82.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 86.0ms
# Speed: 2.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 81.1ms
# Speed: 3.9ms preprocess, 81.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 85.3ms
# Speed: 2.9ms preprocess, 85.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 77.6ms
# Speed: 3.0ms preprocess, 77.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 87.7ms
# Speed: 3.0ms preprocess, 87.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 81.2ms
# Speed: 2.8ms preprocess, 81.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 84.6ms
# Speed: 3.0ms preprocess, 84.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 82.4ms
# Speed: 3.0ms preprocess, 82.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 80.2ms
# Speed: 2.9ms preprocess, 80.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 80.0ms
# Speed: 2.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 80.7ms
# Speed: 3.8ms preprocess, 80.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 81.0ms
# Speed: 2.0ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 86.8ms
# Speed: 3.1ms preprocess, 86.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 77.5ms
# Speed: 2.0ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 81.5ms
# Speed: 3.0ms preprocess, 81.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 79.1ms
# Speed: 2.0ms preprocess, 79.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 81.7ms
# Speed: 3.9ms preprocess, 81.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 81.4ms
# Speed: 4.0ms preprocess, 81.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 77.0ms
# Speed: 2.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 82.2ms
# Speed: 2.1ms preprocess, 82.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 84.5ms
# Speed: 3.8ms preprocess, 84.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 81.9ms
# Speed: 3.0ms preprocess, 81.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 81.4ms
# Speed: 2.0ms preprocess, 81.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 81.8ms
# Speed: 4.0ms preprocess, 81.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 82.3ms
# Speed: 2.0ms preprocess, 82.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 80.0ms
# Speed: 2.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 114.0ms
# Speed: 3.9ms preprocess, 114.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 77.7ms
# Speed: 2.0ms preprocess, 77.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 80.3ms
# Speed: 4.0ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 76.3ms
# Speed: 2.0ms preprocess, 76.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 85.7ms
# Speed: 2.0ms preprocess, 85.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 80.7ms
# Speed: 2.0ms preprocess, 80.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 77.0ms
# Speed: 2.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 84.5ms
# Speed: 3.0ms preprocess, 84.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 94.5ms
# Speed: 2.0ms preprocess, 94.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 80.0ms
# Speed: 2.9ms preprocess, 80.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 79.9ms
# Speed: 2.0ms preprocess, 79.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 83.0ms
# Speed: 3.0ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 82.8ms
# Speed: 2.3ms preprocess, 82.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 103.1ms
# Speed: 2.0ms preprocess, 103.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 80.7ms
# Speed: 4.0ms preprocess, 80.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 80.0ms
# Speed: 2.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 80.6ms
# Speed: 1.9ms preprocess, 80.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 77.0ms
# Speed: 2.0ms preprocess, 77.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 83.0ms
# Speed: 2.9ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 79.4ms
# Speed: 2.0ms preprocess, 79.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 81.1ms
# Speed: 2.0ms preprocess, 81.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 81.1ms
# Speed: 0.9ms preprocess, 81.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 85.4ms
# Speed: 1.9ms preprocess, 85.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 81.8ms
# Speed: 2.0ms preprocess, 81.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 80.0ms
# Speed: 2.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 86.6ms
# Speed: 2.9ms preprocess, 86.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 112.2ms
# Speed: 2.0ms preprocess, 112.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 77.0ms
# Speed: 2.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 79.4ms
# Speed: 3.1ms preprocess, 79.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 80.0ms
# Speed: 2.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 82.7ms
# Speed: 2.1ms preprocess, 82.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 LicensePlate, 77.0ms
# Speed: 2.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
exact_texts = dict()

for filename in os.listdir('../data/main_data/labels'):
    key = os.path.splitext(filename)[0]
    with open(os.path.join('../data/main_data/labels', filename)) as file:
        value = file.readline().strip()
    exact_texts[key] = value

predict_texts = dict()

for filename in os.listdir('../data/main_data/images'):
    key = os.path.splitext(filename)[0]
    image = cv2.imread(os.path.join('../data/main_data/images', filename))
    value = recognize(image)[0]
    predict_texts[key] = value
# Out:
# 0: 640x416 1 LicensePlate, 83.4ms
# Speed: 2.9ms preprocess, 83.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 416x640 1 LicensePlate, 90.7ms
# Speed: 2.0ms preprocess, 90.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 86.5ms
# Speed: 2.0ms preprocess, 86.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 81.0ms
# Speed: 2.0ms preprocess, 81.0ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 78.1ms
# Speed: 2.0ms preprocess, 78.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 94.0ms
# Speed: 5.0ms preprocess, 94.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 67.8ms
# Speed: 1.0ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x416 1 LicensePlate, 78.0ms
# Speed: 2.0ms preprocess, 78.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 71.9ms
# Speed: 2.0ms preprocess, 71.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 62.3ms
# Speed: 2.0ms preprocess, 62.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 63.2ms
# Speed: 2.0ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 1 LicensePlate, 58.9ms
# Speed: 1.0ms preprocess, 58.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 67.0ms
# Speed: 1.0ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 65.0ms
# Speed: 1.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 65.0ms
# Speed: 1.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 65.0ms
# Speed: 1.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 61.3ms
# Speed: 2.0ms preprocess, 61.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 61.2ms
# Speed: 2.0ms preprocess, 61.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x448 1 LicensePlate, 73.5ms
# Speed: 3.0ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x416 1 LicensePlate, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 57.9ms
# Speed: 1.0ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 56.6ms
# Speed: 2.1ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 57.8ms
# Speed: 1.0ms preprocess, 57.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 96.0ms
# Speed: 2.0ms preprocess, 96.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 58.1ms
# Speed: 2.0ms preprocess, 58.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 LicensePlate, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x448 1 LicensePlate, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x448 1 LicensePlate, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x416 1 LicensePlate, 62.4ms
# Speed: 1.0ms preprocess, 62.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 416x640 1 LicensePlate, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 60.0ms
# Speed: 1.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 81.0ms
# Speed: 2.0ms preprocess, 81.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 86.0ms
# Speed: 2.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 80.0ms
# Speed: 2.0ms preprocess, 80.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x416 1 LicensePlate, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 416x640 1 LicensePlate, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 69.0ms
# Speed: 1.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 65.0ms
# Speed: 1.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 66.2ms
# Speed: 1.0ms preprocess, 66.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 LicensePlates, 69.0ms
# Speed: 1.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 68.4ms
# Speed: 2.0ms preprocess, 68.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x416 1 LicensePlate, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 416x640 1 LicensePlate, 65.0ms
# Speed: 1.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 65.0ms
# Speed: 1.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 66.0ms
# Speed: 1.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 68.0ms
# Speed: 1.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 65.5ms
# Speed: 2.0ms preprocess, 65.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x480 1 LicensePlate, 83.0ms
# Speed: 1.0ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 416x640 1 LicensePlate, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 67.9ms
# Speed: 1.0ms preprocess, 67.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 60.0ms
# Speed: 1.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x416 1 LicensePlate, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 416x640 1 LicensePlate, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 71.0ms
# Speed: 1.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 67.0ms
# Speed: 1.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 67.0ms
# Speed: 1.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 70.0ms
# Speed: 1.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 70.0ms
# Speed: 1.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x416 1 LicensePlate, 59.0ms
# Speed: 1.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 416x640 1 LicensePlate, 56.8ms
# Speed: 2.0ms preprocess, 56.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 60.0ms
# Speed: 1.0ms preprocess, 60.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 58.0ms
# Speed: 1.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 55.1ms
# Speed: 1.0ms preprocess, 55.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 59.9ms
# Speed: 1.0ms preprocess, 59.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 61.7ms
# Speed: 1.0ms preprocess, 61.7ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 54.4ms
# Speed: 1.0ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 59.8ms
# Speed: 1.0ms preprocess, 59.8ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x544 1 LicensePlate, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 416x640 1 LicensePlate, 55.0ms
# Speed: 1.0ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 58.2ms
# Speed: 1.0ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 2 LicensePlates, 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 56.3ms
# Speed: 1.0ms preprocess, 56.3ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 60.0ms
# Speed: 1.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)

# %%
absolute_accuracy = sum(predict_texts[key] == exact_texts[key] for key in predict_texts.keys()) / len(predict_texts)

def is_one_character_different(str1, str2):
    return len(str1) == len(str2) and sum(c1 != c2 for c1, c2 in zip(str1, str2)) == 1

relative_accuracy = sum(is_one_character_different(predict_texts[key], exact_texts[key]) for key in predict_texts.keys()) / len(predict_texts)

print('Absolute accuracy:')
print(absolute_accuracy)
print('Relative accuracy:')
print(relative_accuracy)
# Out:
# Absolute accuracy:
# 0.575
# Relative accuracy:
# 0.18333333333333332

# %%
def process_license_plate(input_image_path):
    import cv2
    import numpy as np
    from skimage.morphology import disk, opening
    import matplotlib.pyplot as plt

    def plot_img(img):
        plt.imshow(img, cmap='gray' if len(img.shape) == 2 else None)
        plt.show()

    def resize_image(image, width=472, height=303):
        return cv2.resize(image, (width, height), cv2.INTER_CUBIC)
    
    def apply_blur(image):
        gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        blurred_image = cv2.medianBlur(gray_image, 3)
        return cv2.GaussianBlur(blurred_image, (3, 3), 3)

    
    def threshold_image(image):
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(15, 15))
        contrast_enhanced = clahe.apply(image)
        struct_element = disk(20)
        opened_image = opening(contrast_enhanced, struct_element)
        enhanced_image = cv2.subtract(contrast_enhanced, opened_image.astype(np.uint8))
        _, binary_image = cv2.threshold(enhanced_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
        return cv2.convertScaleAbs(cv2.equalizeHist(binary_image), alpha=1.5, beta=0)

    
    def clean_image(image):
        kernel = cv2.getStructuringElement(cv2.MORPH_CROSS, (3, 3))
        eroded_image = cv2.erode(image, kernel, iterations=2)
        h, w = eroded_image.shape
        mask = np.zeros((h + 2, w + 2), np.uint8)
        flood_filled = eroded_image.copy()
        cv2.floodFill(flood_filled, mask, seedPoint=(0, 0), newVal=255, loDiff=(10,), upDiff=(10,))
        inverted_filled = cv2.bitwise_not(flood_filled)
        return cv2.bitwise_or(eroded_image, inverted_filled)


    def extract_license_plates(original_image, processed_image):
        contours, _ = cv2.findContours(processed_image, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        plates = []
        for contour in contours:
            x, y, w, h = cv2.boundingRect(contour)
            aspect_ratio = w / h
            area = w * h

            if 0.5 < aspect_ratio < 2 and w > 50 and h > 20 and 1000 < area < 9500:
                plate = original_image[y:y + h, x:x + w]
                plt.imshow(plate, cmap='gray')
                plt.title("Detected License Plate")
                plt.show()
                plates.append(plate)
        return plates

    image = cv2.imread(input_image_path)
    resized_image = resize_image(image)
    blurred_image = apply_blur(resized_image)
    thresholded_image = threshold_image(blurred_image)
    cleaned_image = clean_image(thresholded_image)
    license_plates = extract_license_plates(resized_image, cleaned_image)

    return license_plates
